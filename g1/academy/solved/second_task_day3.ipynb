# %%
from sdk_wrapper import *

# %%
g1 = G1("eth0")

# %%
g1.release_arms()
# Out:
# {'final_arm_sdk_weight': 0.0, 'joint_count': 17}

# %%
g1.release_fingers()
# Out:
# {'hand': 'right', 'ok': True, 'action': 'release_dex3_fingers'}

# %%
g1.teach("wave_both_arms") #### arms were not movable after teach is executed
# Out:
# [teach] left Dex3 hand not accessible -- its fingers will not be recorded.
# collected 140 samples (3.3s)...
# Move the arms/fingers by hand; press Enter when the motion is complete...
# collected 143 samples (3.3s) - recording complete.
# {'sequence': 'wave_both_arms',
#  'samples': 143,
#  'duration_s': 3.3312137126922607,
#  'hands': ['right']}

# %%
g1.repeat("wave_both_arms")
# Out:
# {'sequence': 'wave_both_arms',
#  'samples': 1131,
#  'duration_s': 26.909996271133423,
#  'hands': ['right']}

# %%
g1.release_arms()
# Out:
# {'final_arm_sdk_weight': 0.0, 'joint_count': 17}
