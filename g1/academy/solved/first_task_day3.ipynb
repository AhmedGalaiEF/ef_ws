# %%
from sdk_wrapper import *

# %%
g1 = G1("eth0")

# %%
right_shoulder_roll = 23

# %%
lowstate = g1.get_lowstate()

# %%
current_q = lowstate["joint_positions"][right_shoulder_roll]
print(current_q)
g1.move_ll_joint(right_shoulder_roll, current_q-0.3, dq=0.01, kp=60, kd=10)
# Out:
# -0.03845737874507904
# {'joint_id': 23,
#  'dev_mode': False,
#  'topic': 'rt/arm_sdk',
#  'target': -0.33845737874507903,
#  'steps': 11}

# %%
g1.release_arms()
# Out:
# {'final_arm_sdk_weight': 0.0, 'joint_count': 17}

# %%
current_q = lowstate["joint_positions"][right_shoulder_roll]
print(current_q)
g1.move_ll_joint(right_shoulder_roll, current_q+0.2, dq=0.01, kp=60, kd=10)
# Out:
# -0.03845737874507904
# {'joint_id': 23,
#  'dev_mode': False,
#  'topic': 'rt/arm_sdk',
#  'target': 0.16154262125492097,
#  'steps': 32}

# %%
g1.engage_arms()
# Out:
# {'final_arm_sdk_weight': 1.0, 'joint_count': 17}

# %%
current_q = lowstate["joint_positions"][right_shoulder_roll]
print(current_q)
g1.move_ll_joint(right_shoulder_roll, current_q-0.5, dq=0.01, kp=60, kd=10)
# Out:
# -0.03845737874507904
# {'joint_id': 23,
#  'dev_mode': False,
#  'topic': 'rt/arm_sdk',
#  'target': -0.538457378745079,
#  'steps': 39}

# %%
g1.open_dex3_hand("right")
# Out:
# {'hand': 'right', 'ok': True, 'action': 'open_dex3_hand'}

# %%
g1.close_dex3_hand("right")
# Out:
# {'hand': 'right', 'ok': True, 'action': 'close_dex3_hand'}

# %%
g1.release_fingers()
# Out:
# {'hand': 'right', 'ok': True, 'action': 'release_dex3_fingers'}

# %%
g1.get_dex3_tactile_pressures()
# Out:
# {'left': None,
#  'right': [[99664.0,
#    30000.0,
#    101152.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    101168.0,
#    30000.0,
#    101528.0],
#   [30000.0,
#    30000.0,
#    30000.0,
#    99696.0,
#    30000.0,
#    30000.0,
#    101592.0,
#    30000.0,
#    101352.0,
#    30000.0,
#    30000.0,
#    30000.0],
#   [100904.0,
#    30000.0,
#    100968.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    100896.0,
#    30000.0,
#    100624.0],
#   [30000.0,
#    30000.0,
#    30000.0,
#    99672.0,
#    30000.0,
#    30000.0,
#    99672.0,
#    30000.0,
#    99704.0,
#    30000.0,
#    30000.0,
#    30000.0],
#   [99688.0,
#    30000.0,
#    101016.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    30000.0,
#    101488.0,
#    30000.0,
#    102176.0],
#   [30000.0,
#    30000.0,
#    30000.0,
#    99664.0,
#    30000.0,
#    30000.0,
#    101224.0,
#    30000.0,
# ...
