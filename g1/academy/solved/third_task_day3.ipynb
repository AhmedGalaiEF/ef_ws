# %%
from sdk_wrapper import *

# %%
g1 = G1("eth0")

# %%
g1.engage_arms()
# Out:
# {'final_arm_sdk_weight': 1.0, 'joint_count': 17}

# %%
g1.ik_move_ee(hand="right",pose_increment=(1,0,1,0,0,0), max_speed=0.35, max_dq=0.2, rate_hz=50.0, position_only=True)
# Out:
# {'hand': 'right',
#  'success': True,
#  'pose_increment': [1, 0, 1, 0, 0, 0],
#  'position_only': True,
#  'ik': {'iterations': 5,
#   'error_pos_m': 0.0019969842999572537,
#   'mode': 'fallback_position'},
#  'joint_targets': {22: -0.3986025869846344,
#   23: -0.18548575971231565,
#   24: 0.021738431792545768,
#   25: 0.8296965837478638,
#   26: -0.3738818156649698,
#   27: 0.5712593019008636,
#   28: -0.1054206921692333},
#  'ee_pose': {'x': 0.2509898862507152,
#   'y': -0.20896378720318592,
#   'z': 0.015413564719580584},
#  'steps': 29}
